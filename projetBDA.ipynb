# %% [markdown]
# PROJET BASE DE DONNEES AVANCEE
#
# Amadou Asmaou & Bardinet Romain

# %% [markdown]
# Etape 1
#
# Affiche chaque attribut et la part qu'il représente dans sa catégorie

# %%
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape1
# Out:
# {'DayOfWeek.beginning': 0.0, 'DayOfWeek.end': 0.9979919678714859, 'DayOfWeek.weekend': 0.0, 'DepTime.morning': 0.28076305220883535, 'DepTime.midday': 0.16261617900172118, 'DepTime.afternoon': 0.24666092943201376, 'DepTime.evening': 0.2777796901893287, 'DepTime.night': 0.020131956397016648, 'ArrTime.morning': 0.0, 'ArrTime.midday': 0.0, 'ArrTime.afternoon': 0.002008032128514056, 'ArrTime.evening': 0.002008032128514056, 'ArrTime.night': 0.9839357429718876, 'AirTime.veryShort': 0.5762382864792506, 'AirTime.short': 0.31628179384203464, 'AirTime.medium': 0.09508032128514056, 'AirTime.long': 0.0003514056224899598, 'AirTime.veryLong': 0.0, 'ArrDelay.early': 0.24096385542168675, 'ArrDelay.onTime': 0.06124497991967871, 'ArrDelay.short': 0.060240963855421686, 'ArrDelay.acceptable': 0.12349397590361445, 'ArrDelay.long': 0.3123159303882195, 'ArrDelay.veryLong': 0.1896921017402945, 'DepDelay.none': 0.13855421686746988, 'DepDelay.short': 0.0642570281124498, 'DepDelay.acceptable': 0.139056224899598
# ...

# %% [markdown]
# Etape 2 :
#
# Affiche chaque attribut et la part qu'il représente dans sa catégorie.
# Prend cette fois en paramètre un dictionnaire python de la forme :
#
# {attribut : valeur}
#
# Le dictionnaire alors retourné contient les memes calculs qu'à l'étape 1 à la seule différence que seuls les vols correspondant au filtre imposé sont pris en compte.
#
# Par exemple :
#
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape2 {"ArrTime.evening": 1} renvoie un dictionnaire de proportions similaire au précédent, seuls les vols arrivant en fin de journée sont pris en compte.
#
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape2 {"ArrTime.evening": 1, "Distance.veryShort : 1"} seuls les vols arrivant en fin de journée et effectués sur une courte distance sont pris en compte.

# %%
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape2 {"ArrTime.evening": 1}
# Out:
# {'DayOfWeek.beginning': 0.0, 'DayOfWeek.end': 0.9979919678714859, 'DayOfWeek.weekend': 0.0, 'DepTime.morning': 0.28076305220883535, 'DepTime.midday': 0.16261617900172118, 'DepTime.afternoon': 0.24666092943201376, 'DepTime.evening': 0.2777796901893287, 'DepTime.night': 0.020131956397016648, 'ArrTime.morning': 0.0, 'ArrTime.midday': 0.0, 'ArrTime.afternoon': 0.002008032128514056, 'ArrTime.evening': 0.002008032128514056, 'ArrTime.night': 0.9839357429718876, 'AirTime.veryShort': 0.5762382864792506, 'AirTime.short': 0.31628179384203464, 'AirTime.medium': 0.09508032128514056, 'AirTime.long': 0.0003514056224899598, 'AirTime.veryLong': 0.0, 'ArrDelay.early': 0.24096385542168675, 'ArrDelay.onTime': 0.06124497991967871, 'ArrDelay.short': 0.060240963855421686, 'ArrDelay.acceptable': 0.12349397590361445, 'ArrDelay.long': 0.3123159303882195, 'ArrDelay.veryLong': 0.1896921017402945, 'DepDelay.none': 0.13855421686746988, 'DepDelay.short': 0.0642570281124498, 'DepDelay.acceptable': 0.139056224899598
# ...

# %% [markdown]
# Etape 3 Correlation :
#
# Retourne le degré de corrélation entre chaque attribut.
#
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Correlation [OPTIONEL](str)attribut.rang [OPTIONEL](int)proportion
#
#
# Par exemple :
#
#
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Correlation
#
# Renvoie pour chacun des attributs, son degré de corrélation avec chacun des autres attributs dans la base de données. Complexité = nb_attributs * nb_attributs * nb_vols * nb_filtres
# (temps de calcul d'environ 4min sur Ryzen 4800H / Python 3.9.5)
#
#
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Correlation ArrTime.evening 1
#
# Renvoie pour l'attribut, son degré de corrélation avec chacun des autres attributs dans la base de données. Complexité nb_attributs * nb_vols * nb_filtres
# (temps de calcul d'environ 4 secondes sur Ryzen 4800H / Python 3.9.5)

# %%
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Correlation
# Out:
# CORRELATING  DayOfWeek.beginning  TO :
# == DayOfWeek.beginning
# correlation =  0
# == DayOfWeek.end
# correlation =  0.002008032128514192
# == DayOfWeek.weekend
# correlation =  0
# == DepTime.morning
# correlation =  0
# == DepTime.midday
# correlation =  0
# == DepTime.afternoon
# correlation =  0.7533390705679862
# == DepTime.evening
# correlation =  0
# == DepTime.night
# correlation =  0
# == ArrTime.morning
# correlation =  0
# == ArrTime.midday
# correlation =  0
# == ArrTime.afternoon
# correlation =  0
# == ArrTime.evening
# correlation =  0
# == ArrTime.night
# correlation =  0.016064257028112428
# == AirTime.veryShort
# correlation =  0
# == AirTime.short
# correlation =  0.5874585297712591
# == AirTime.medium
# correlation =  0
# == AirTime.long
# correlation =  0
# == AirTime.veryLong
# correlation =  0
# == ArrDelay.early
# correlation =  0
# == ArrDelay.onTime
# correlation =  0
# == ArrDelay.short
# correlation =  0
# == ArrDelay.acceptable
# ...

# %%
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Correlation ArrTime.evening 1
# Out:
# correlation =  0.1929191559314768
# == Distance.long
# correlation =  0.2710114384932468
# == Distance.veryLong
# correlation =  0
# == Month.winter
# correlation =  0.002008032128514192
# == Month.spring
# correlation =  0
# == Month.summer
# correlation =  0
# == Month.autumn
# correlation =  0
# == DayOfMonth.beginning
# correlation =  0
# == DayOfMonth.middle
# correlation =  0
# == DayOfMonth.end
# correlation =  0
# == TaxiIn.short
# correlation =  0.025862710099658126
# == TaxiIn.medium
# correlation =  0
# == TaxiIn.long
# correlation =  0
# == TaxiOut.short
# correlation =  0
# == TaxiOut.medium
# correlation =  0.5493807290229622
# == TaxiOut.long
# correlation =  0
# == CarrierDelay.none
# correlation =  0.0673806336456938
# == CarrierDelay.short
# correlation =  0
# == CarrierDelay.acceptable
# correlation =  0
# == CarrierDelay.long
# correlation =  0.014846367719398179
# == CarrierDelay.veryLong
# correlation =  0
# == WeatherDelay.none
# correlation =  0
# ...

# %% [markdown]
# On constate ici des corrélation logiques, comme par exemple la forte correlation entre DepTime.evening et ArrTime.evening, pour des airTime courts.

# %% [markdown]
# Etape 3 Atypicité :
#
# Retourne le degré d'atypicité de chacun des attributs.
#
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Atypicality

# %%
# !python3 ./Src/rewriterFromCSV.py ./Data/FlightsVoc.txt ./Data/extrait_2008.csv etape3_Atypicality
# Out:
# {'DayOfWeek.beginning': 1, 'DayOfWeek.end': 0.002008032128514081, 'DayOfWeek.weekend': 1, 'DepTime.morning': 0.7192369477911646, 'DepTime.midday': 0.8373838209982788, 'DepTime.afternoon': 0.7533390705679862, 'DepTime.evening': 0.7222203098106713, 'DepTime.night': 0.9798680436029834, 'ArrTime.morning': 1, 'ArrTime.midday': 1, 'ArrTime.afternoon': 0.9979919678714859, 'ArrTime.evening': 0.9979919678714859, 'ArrTime.night': 0.016064257028112428, 'AirTime.veryShort': 0.42376171352074943, 'AirTime.short': 0.6837182061579654, 'AirTime.medium': 0.9049196787148595, 'AirTime.long': 0.9996485943775101, 'AirTime.veryLong': 1, 'ArrDelay.early': 0.7590361445783133, 'ArrDelay.onTime': 0.9387550200803213, 'ArrDelay.short': 0.9397590361445783, 'ArrDelay.acceptable': 0.8765060240963856, 'ArrDelay.long': 0.6876840696117805, 'ArrDelay.veryLong': 0.8103078982597055, 'DepDelay.none': 0.8614457831325302, 'DepDelay.short': 0.9357429718875502, 'DepDelay.acceptable': 0.8609437751004017, 'DepDelay.long': 0.658
# ...
